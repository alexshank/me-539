# %% [markdown]
# # Homework 3
#
# **Due 9/29/2020.**
#
#
# ## References
#
# + Lectures 7-10 (inclusive).
#
# ## Instructions
#
# + Type your name and email in the "Student details" section below.
# + Develop the code and generate the figures you need to solve the problems using this notebook.
# + For the answers that require a mathematical proof or derivation you can either:
#
#     - Type the answer using the built-in latex capabilities. In this case, simply export the notebook as a pdf and upload it on gradescope; or
#     - You can print the notebook (after you are done with all the code), write your answers by hand, scan, turn your response to a single pdf, and upload on gradescope.
#
# **Note**:
# + Please match all the pages corresponding to each of the questions when you submit on gradescope.
#
# **Important:**
# If you are running the notebook on Google Colab make sure you make a copy on your Google Drive so that you can resume your work later. To do this click on "File->Save a copy in Drive." Rename the copy as you wish by clicking on the filename you see on the very top. Then make sure you save regularly. If you close your browser, you can resume your work by going to your Google Drive and clicking on the notebook. You can find the notebooks the folder "My Drive/Colab Notebooks."

# %% [markdown]
# ## Student details
#
# + **First Name:**
# + **Last Name:**
# + **Email:**

# %%
# Here are some modules that you may need - please run this block of code:
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context('paper')
import numpy as np
import scipy
import scipy.stats as st

# %% [markdown]
# ## Problem 1
# ### Part A
# Let $X$ be a continuous random variable with CDF:
# $$
# F(x) = p(X \le x).
# $$
# Show that the random variable
# $$
# Z = F(X)
# $$
#     is distributed uniformly in $[0,1]$.
#     Hint: Show that:
# $$
#     F_Z(z) := p(Z \le z) = z.
# $$
# **Proof:**

# %% [markdown]
# We have:
# $$
# \begin{split}
# F_Z(z) &= p(Z\le z)\\
# &= p(F(X) \le z)\\
# &= p(X \le F^{-1}(z))\\
# &= F(F^{-1}(z))\\
# &=z.
# \end{split}
# $$

# %% [markdown]
# ### Part B

# %% [markdown]
# **Note (Before you attempt this part of the problem):** To do this problem your Jupyter notebook needs to be able to see this data file: [hw_03_p1B_data.txt](https://raw.githubusercontent.com/PredictiveScienceLab/data-analytics-se/master/homework/hw_03_p1B_data.txt).
# For this to happen the file must be in the same folder as the Jupyter notebook notebook.
# There are two cases:
# + If you are using Google Colab:
#     - In this Jupyter notebook do "File->Save A Copy in Drive"
#     - Write click on [hw_03_p1B_data.txt](https://raw.githubusercontent.com/PredictiveScienceLab/data-analytics-se/master/homework/hw_03_p1B_data.txt) and click "Save Link As." Make sure that you save the link as text and that you make a note where it is.
#     - Open your Google Drive in a separate tab. Go to the folder "Colab Notebooks" which was automatically created when you saved a copy of the notebook. Drag and drop the hw_03_p1B_data.txt file you just downloaded in that folder.
# + If you are running the Jupyter notebook on your own computer:
#     - If you cloned the github repository, then the file will be there.
#     - If you downloaded the notebook manually, then download the file as per the instructions for Google Colab and put it in the same folder as the Jupyter notebook.
#
# The theorem you have just proved is very useful when you want to test if a set of observations $x_1,x_2,\dots,x_N$ has been indeed independent realizations of a random variable $X$ with CDF $F(x)$.
# Part A proves that, if this hypothesis is valid, then the transformed dataset $z_1,z_2,\dots,z_N$, where
# $$
# z_i = F(x_i),
# $$
# should be distributed uniformely in $[0,1]$.
# In other words, the empirical histrogram of $z_1,z_2,\dots,z_N$ should be a flat line.
# Use this observation to find the distribution from which this dataset was sampled:

# %%
# If the following fails, please read the intructions above
data = np.loadtxt('hw_03_p1B_data.txt')
fig, ax = plt.subplots()
ax.hist(data, density=True, alpha=0.5)
ax.set_xlabel('$x$')
ax.set_ylabel('Empirical PDF')
ax.set_title('Histogram of data');
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-f725c5507a32> in <module>()
#       1 # If the following fails, please read the intructions above
# ----> 2 data = np.loadtxt('hw_03_p1B_data.txt')
#       3 fig, ax = plt.subplots()
#       4 ax.hist(data, density=True, alpha=0.5)
#       5 ax.set_xlabel('$x$')
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: hw_03_p1B_data.txt not found.

# %% [markdown]
# The correct distribution is one of the following:
#
# 1. Standard normal, $\mathcal{N}(0,1)$;
#
# 2. Normal with mean 2 and variance 2, $\mathcal{N}(2,2)$; or
#
# 3. Exponential with rate parameter $1$, $\mathcal{E}(1)$; or
#
# 4. Exponential with rate parameter $2$, $\mathcal{E}(2)$; or
#
# 5. Exponential with rate parameter $10$, $\mathcal{E}(10)$; or
#
# 6. Gamma distribution with parameters $\alpha=2.$ and $\beta=3.$.
#
# Systematically go over these distributions and try to determine which one generated the data.
# All the required CDF's and inverse CDF's are implemented in [scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html).
# Check also [scipy.stats.rv_continuous](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.rv_continuous.html#scipy.stats.rv_continuous).)
# Please pay special attention to the defintiion of the probability distributions of the various random variables and how you can control their parameters.
# As a hint, here is how you can test for $\mathcal{N}(0,1)$:

# %%
# Testing for N(0,1):
#transformed_data = st.gamma(a=2, scale=1/3).cdf(data) # cdf() gives the CDF of a random variable
transformed_data = st.expon(scale=1/10).cdf(data)
# If the data came from N(0,1), the histogram of the transformed_data should match that of a uniform:
fig, ax = plt.subplots()
ax.hist(transformed_data, density=True, alpha=0.5)
ax.plot(np.linspace(0, 1,50), np.ones(50), lw=2, color='r') # This is the line that you should try to much.
ax.set_xlabel('$z = F(x)$')
ax.set_ylabel('Empirical PDF')
ax.set_title('Testing the $\mathcal{N}(0,1)$');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-da5690c165e4> in <module>()
#       1 # Testing for N(0,1):
#       2 #transformed_data = st.gamma(a=2, scale=1/3).cdf(data) # cdf() gives the CDF of a random variable
# ----> 3 transformed_data = st.expon(scale=1/10).cdf(data)
#       4 # If the data came from N(0,1), the histogram of the transformed_data should match that of a uniform:
#       5 fig, ax = plt.subplots()
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Problem 2
#
# **Note:** This problem also requires a data file. This file: [hw_03_p2_data.txt](https://raw.githubusercontent.com/PredictiveScienceLab/data-analytics-se/master/homework/hw_03_p2_data.txt). Please follow the same directions we gave in Part B of Problem 1 above.
#
# Consider the following data set $x_1,\dots,x_N$:

# %%
# If the following fails, please look at the note above.
data = np.loadtxt('hw_03_p2_data.txt')
data = np.array(data)
fig, ax = plt.subplots()
ax.hist(data, alpha=0.5)
ax.set_xlabel('$x$')
ax.set_ylabel('Empirical PDF')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-cb54bd8d1155> in <module>()
#       1 # If the following fails, please look at the note above.
# ----> 2 data = np.loadtxt('hw_03_p2_data.txt')
#       3 data = np.array(data)
#       4 fig, ax = plt.subplots()
#       5 ax.hist(data, alpha=0.5)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: hw_03_p2_data.txt not found.

# %% [markdown]
# Your goal is to generate a procedure that samples from the same distribution as the observed data.
# This is a variation of the standard *density estimation* problem.
# In general, this is a very difficult problem and we will see various ways to solve it later on.
# In this problem, you will develop a simple method that relies on the empirical CDF of the observed data.
# Needless to say, this method works only for one dimensional cases in which you have a lot of observations.
#
# The [empirical CDF](https://en.wikipedia.org/wiki/Empirical_distribution_function) of our data set, $x_1,\dots,x_N$ is defined to be:
# $$
# \hat{F}_N(x) = \frac{\text{Number of observations}\;\le x}{N} = \frac{1}{N}\sum_{i=1}^N 1_{[x_i,+\infty]}(x),
# $$
# where $1_A(x)$ is the [indicator function](https://en.wikipedia.org/wiki/Indicator_function) of the set $A$.
# Using the, so called, [strong law of large numbers](https://en.wikipedia.org/wiki/Law_of_large_numbers#Strong_law), we can show that $\hat{F}_N(x)$ converges to the true CDF of the data as $N\rightarrow+\infty$.

# %% [markdown]
# ### Part A
#
# Complete the code that calculates the empirical CDF:

# %%
def myECDF_base(x):
    """
    Make this code work if ``x`` is a simple scalar.
    
    :param x:    The point at which you want to observe the PDF.
    :returns:    The value of the empirical CDF at ``x``.
    """
    N = data.shape[0]
    # Write your code here (delete the next line and return the right value)
    s = 0
    for i in range(N):
        if data[i] <= x:
            s += 1
    return s / N

# Vectorize your function (i.e., make it work with 1D numpy arrays).
# See this: https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.vectorize.html
myECDF = np.vectorize(myECDF_base)

# %%
# You can test your results by comparing the empirical CDF you can get with of scipy.stats
# The two should match almost exactly
hist_rv = st.rv_histogram(np.histogram(data, bins=1000))
fig, ax = plt.subplots()
# The range in which the x's takes values:
x_min = data.min()
x_max = data.max()
xx = np.linspace(x_min, x_max, 100)
ax.plot(xx, myECDF(xx), label='My empirical CDF')
ax.plot(xx, hist_rv.cdf(xx), '--', label='Empirical CDF from scipy.stats')
ax.set_xlabel('$x$')
ax.set_ylabel('Empirical CDF')
plt.legend(loc='best');

# %% [markdown]
# ### Part B
#
# Now complete the code that computes the inverse of the empirical CDF $\hat{F}^{-1}$.
# There are may ways of doing this.
# Let's do it in a way that will teach us something about the root finding toolbox of numpy (see [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.root_scalar.html#scipy.optimize.root_scalar)).
# Mathematically, we wish to find a function $F^{-1}$ such that
# $$
# F(F^{-1}(u))) = u,
# $$
# for any $u\in[0,1]$ (the domain in which $F(x)$ takes values).
# It is obvious that $F^{-1}(u)$ is the solution to the *root finding* problem:
# $$
# F(x^*) = u.
# $$
# Since we know that $F$ is increasing, this problem must have a unique solution for any $u\in[0,1]$.
# To find this solution, we can use [Brent's method](https://en.wikipedia.org/wiki/Brent%27s_method).
# Please note, that the problem that this code solves is of the form:
# $$
# g(x^*) = 0.
# $$
# So, you will have to reformulate the original problem as:
# $$
# F(x^*) - u = 0.
# $$
# Study the [numpy implementation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.brentq.html#scipy.optimize.brentq) of Brent's method and complete the following code:

# %%
from scipy import optimize    # Gives you access to optimize.brentq

def myiECDF_base(u):
    """
    Evaluates the inverse of the empirical CDF.
    
    :param u:   A scalar at which to evaluate the function.
    :returns:    The value of the inverse of the empirical CDF at ``u``.
    """
    # Write your code here
    # You will have to define a function to pass to optimize.brentq
    # You can define this function in here
    def g(x):
        return myECDF_base(x) - u
    res = optimize.root_scalar(g, bracket=[-6, 6], method='brentq')
    x_star = res.root
    return x_star

# Vectorize your function (i.e., make it work with 1D numpy arrays).
# See this: https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.vectorize.html
myiECDF = np.vectorize(myiECDF_base)

# %%
# You can test your results by comparing the inverse of the empirical CDF you can get with scipy.stats
# The two should match almost exactly
hist_rv = st.rv_histogram(np.histogram(data, bins=1000))
fig, ax = plt.subplots()
uu = np.linspace(1e-3, 1, 100)    # For convergence issues we cannot start at 0
ax.plot(uu, myiECDF(uu), label='Inverse of my empirical CDF')
ax.plot(uu, hist_rv.ppf(uu), '--', label='Inverse of empirical CDF from scipy.stats')
ax.set_xlabel('$x$')
ax.set_ylabel('Inverse of empirical CDF')
plt.legend(loc='best')

# %% [markdown]
# ### Part C
#
# Now use the *inverse transform sampling* method to generate samples from same distribution as the original data.
# That is, you can now generate uniform samples:
# $$
# u_i \sim U([0,1]),
# $$
# and transform them as:
# $$
# \hat{x}_i = {\hat{F}}^{-1}(u_i).
# $$
# The $\hat{x}_i$'s generated in this way should have the same distribution of the data you started with.
# Verify this by comparing the histrogram of $1,000$ $\hat{x}_i$ samples with the original data of this problem.

# %%
u = np.random.rand(1000)
x = myiECDF(u)

fig, ax = plt.subplots()
ax.hist(data, density=True, alpha=0.25, label='Original data')
ax.hist(x, density=True, alpha=0.25, label='Generated data')
ax.set_xlabel('$x$')
ax.set_ylabel('$p(x)$')
plt.legend(loc='best');

# %% [markdown]
# ## Problem 3
#
# This is a classic uncertainty propagation problem that you will have to solve using Monte Carlo sampling.
# Consider the following stochastic harmonic oscillator:
# $$
# \begin{array}{ccc}
# \ddot{y} + 2 \zeta \omega(X) \dot{y} + \omega^2(X)y &=& 0,\\
# y(0) &=& y_0(X),\\
# \dot{y}(0) &=& v_0(X),
# \end{array}
# $$
# where:
# + $X = (X_1, X_2, X_3)$,
# + $X_i \sim N(0, 1)$,
# + $\omega(X) = 2\pi + X_1$,
# + $\zeta = 0.01$,
# + $y_0(X) = 1+ 0.1 X_2$, and
# + $v_0 = 0.1 X_3$.
#
# In words, this stochastic harmonic oscillator has an uncertain natural frequency and uncertain initial conditions.
#
# Our goal is to propagate uncertainty through this dynamical system, i.e., estimate the mean and variance of its solution.
# A solver for this dynamical system is given below:

# %%
class Solver(object):
    def __init__(self, nt=100, T=5):
        """
        This is the initializer of the class.
        
        Arguments:
            nt - The number of timesteps.
            T  - The final time.
        """
        self.nt = nt
        self.T = T
        self.t = np.linspace(0, T, nt) # The timesteps on which we will get the solution
        # The following are not essential, but they are convenient
        self.num_input = 3             # The number of inputs the class accepts
        self.num_output = nt           # The number of outputs the class returns
        
    def __call__(self, x):
        """
        This special class method emulates a function call.
        
        Arguments:
            x - A 1D numpy array with 3 elements. This represents the stochastic input x = (x1, x2, x3).
        """
        ##uncertain quantities 
        x1 = x[0]
        x2 = x[1]
        x3 = x[2]
        
        #ODE parameters 
        omega = 2*np.pi + x1 
        y10 = 1 + 0.1*x2
        y20 = 0.1*x3
        y0 = np.array([y10, y20])   #initial conditions 
        
        #coefficient matrix 
        zeta = 0.01
        k = omega**2    ##spring constant
        c = 2*zeta*omega   ##damping coeff. 
        C = np.array([[0, 1],[-k, -c]])
        
        #RHS of the ODE system
        def rhs(y, t):
            return np.dot(C, y)
        
        y = scipy.integrate.odeint(rhs, y0, self.t)
        
        return y

# %% [markdown]
# Let's plot a few samples of the forward model to demonstrate how the solver works.

# %%
# 1. Create the solver object
solver = Solver()
fig1, ax1 = plt.subplots()
ax1.set_xlabel('$t$ (Time)')
ax1.set_ylabel('$y(t)$ (Position)')
fig2, ax2 = plt.subplots()
ax2.set_xlabel('$t$ (Time)')
ax2.set_ylabel('$\dot{y}(t)$ (Velocity)')
for i in range(2):
    # Sample the random inputs (they are just standard normal)
    x = np.random.randn(solver.num_input) # solver.num_input is just 3
    # Evaluate the solver response
    y = solver(x) # This returns an (num timesteps) x (num states) array (100 x 2 here)
    # Plot the sample
    ax1.plot(solver.t, y[:, 0])
    ax2.plot(solver.t, y[:, 1], label='Sample {0:d}'.format(i+1))
plt.legend(loc=True)

# %% [markdown]
# For your convenience, here is code that takes many samples of the solver at once:

# %%
def take_samples_from_solver(num_samples):
    """
    Takes ``num_samples`` from the ODE solver.
    
    Returns them in an array of the form: ``num_samples x 100 x 2`` (100 timesteps, 2 states (position, velocity))
    """
    samples = np.ndarray((num_samples, 100, 2))
    for i in range(num_samples):
        samples[i, :, :] = solver(np.random.randn(solver.num_input))
    return samples

# %% [markdown]
# It works like this:

# %%
samples = take_samples_from_solver(50)
print(samples.shape)
print(samples)
# Out:
# (50, 100, 2)
# [[[ 0.89641127 -0.15085935]
#   [ 0.83240826 -2.35395632]
#   [ 0.66392172 -4.24459566]
#   ...
#   [-0.62740269  0.6769386 ]
#   [-0.55446238  2.17885407]
#   [-0.41214218  3.39538355]]
#
#  [[ 0.96596828  0.02084832]
#   [ 0.92073162 -1.79585991]
#   [ 0.78766187 -3.42943695]
#   ...
#   [ 0.22158829  4.16960017]
#   [ 0.4175367   3.52794599]
#   [ 0.57231166  2.55264858]]
#
#  [[ 0.99537748  0.068819  ]
#   [ 0.95615031 -1.60935525]
#   [ 0.8353088  -3.13993147]
#   ...
#   [-0.72947867  1.01967929]
#   [-0.6476161   2.19752693]
#   [-0.51079905  3.18036427]]
#
#  ...
#
#  [[ 1.00870797  0.06492066]
#   [ 0.94974703 -2.37255202]
#   [ 0.77428505 -4.50079441]
#   ...
#   [-0.6826847  -1.46584193]
#   [-0.71286112  0.28124677]
#   [-0.65507009  1.98141142]]
#
#  [[ 0.98074911  0.01442013]
#   [ 0.93654914 -1.74943392]
#   [ 0.80692294 -3.34251878]
#   ...
#   [-0.25681841  4.1316651 ]
#   [-0.04021245  4.37946574]
#   [ 0.17875947  4.22504258]]
#
#  [[ 1.09533705  0.06879649]
#   [ 1.00395624 -3.62903237]
#   [ 0.73991039 -6.66906298]
#   ...
#   [-0.71967274 -0.91776976]
#   [-0.70224096  1.59437765]
#   [-0.56364608  3.81011173]]]

# %% [markdown]
# ### Part A
# Take 100 samples of the solver output and plot the estimated mean position and velocity as a function of time along with a 95\% epistemic uncertainty interval around it.
# This interval captures how sure you are about the mean response when using only 100 Monte Carlo samples.
# You need to use the central limit theorem to find it (see the lecture notes).

# %%
samples = take_samples_from_solver(10000) # I came back here later and changed this
                                          # to a higher number.
# Sampled positions are: samples[:, :, 0]
# Sampled velocities are: samples[:, :, 1]
# Sampled position at the 10th timestep is: samples[:, 9, 0]
# etc.

sampled_positions = samples[:, :, 0]
sampled_velocities = samples[:, :, 1]
# Prediction for positions
mean_position = np.mean(sampled_positions, axis=0)


# We are going to apply the CLM to get the 95% epistemic uncertainty
# We need an estimate of the variance at each timestep
var_position = np.var(sampled_positions, axis=0)

print(mean_position)
# Now get the CLM variance (which is this variance divided by the number of samples)
clm_var_position = var_position / samples.shape[0]

print(samples.shape[0])
print(var_position)
# and the standard devivation used in CLM
clm_std_position = np.sqrt(clm_var_position)
# Lower bound to position

print(clm_std_position)
mean_position_lower = mean_position - 1.96 * clm_std_position
# Upper bound to position
mean_position_upper = mean_position + 1.96 * clm_std_position

# Plot it
fig, ax = plt.subplots()
ax.plot(solver.t, mean_position, label='Mean position')
ax.fill_between(solver.t, mean_position_lower, mean_position_upper,
                label='95% credible interval', color='blue', alpha=0.25)
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$y(t)$ (Position)')
plt.legend(loc='best');

# Prediction for velocities
mean_velocity = np.mean(sampled_velocities, axis=0)
# We are going to apply the CLM to get the 95% epistemic uncertainty
# We need an estimate of the variance at each timestep
var_velocity = np.var(sampled_velocities, axis=0)
# Now get the CLM variance (which is this variance divided by the number of samples)
clm_var_velocity = var_velocity / samples.shape[0]
# and the standard devivation used in CLM
clm_std_velocity = np.sqrt(clm_var_velocity)
# Lower bound to position
mean_velocity_lower = mean_velocity - 1.96 * clm_std_velocity
# Upper bound to position
mean_velocity_upper = mean_velocity + 1.96 * clm_std_velocity

# Plot it
fig, ax = plt.subplots()
ax.plot(solver.t, mean_velocity, 'r', label='Mean velocity')
ax.fill_between(solver.t, mean_velocity_lower, mean_velocity_upper,
                label='95% credible interval', color='red', alpha=0.25)
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$\dot{y}(t)$ (Velocity)')
plt.legend(loc='best');
# Out:
# [ 9.99155060e-01  9.48118203e-01  8.01171947e-01  5.75305944e-01
#   2.96002925e-01 -5.86787227e-03 -2.97739017e-01 -5.49142105e-01
#  -7.35139059e-01 -8.38974049e-01 -8.53646816e-01 -7.82257957e-01
#  -6.37140107e-01 -4.37943078e-01 -2.08965247e-01  2.38973722e-02
#   2.36187334e-01  4.07538096e-01  5.23647704e-01  5.77386494e-01
#   5.68975134e-01  5.05291275e-01  3.98467094e-01  2.64013701e-01
#   1.18744624e-01 -2.12318186e-02 -1.42218393e-01 -2.34163080e-01
#  -2.91329175e-01 -3.12389548e-01 -3.00005622e-01 -2.60007205e-01
#  -2.00323015e-01 -1.29821901e-01 -5.72133453e-02  9.87277089e-03
#   6.55466091e-02  1.06022154e-01  1.29688935e-01  1.36930620e-01
#   1.29753237e-01  1.11297906e-01  8.53136661e-02  5.56573328e-02
#   2.58719695e-02 -1.12323542e-03 -2.32181420e-02 -3.91754973e-02
#  -4.85903664e-02 -5.17706540e-02 -4.95679161e-02 -4.31870670e-02
#  -3.39996857e-02 -2.33796445e-02 -1.25729689e-02 -2.60724522e-03
#   5.75965726e-03  1.20558395e-02  1.60832986e-02  1.78851333e-02
#   1.76993644e-02  1.59057024e-02  1.29702859e-02  9.39216096e-03
#   5.65431224e-03  2.18145276e-03 -6.93523426e-04 -2.75269297e-03
#  -3.90437568e-03 -4.18155319e-03 -3.72733376e-03 -2.76858448e-03
#  -1.58028928e-03 -4.44592482e-04  3.90436794e-04  7.46813540e-04
#   5.42250749e-04 -1.98591526e-04 -1.34923364e-03 -2.70245139e-03
#  -4.00433361e-03 -4.99617445e-03 -5.45762742e-03 -5.24417891e-03
#  -4.31279555e-03 -2.73146343e-03 -6.70968039e-04  1.61978938e-03
#   3.85089631e-03  5.73485555e-03  7.02923634e-03  7.57168550e-03
#   7.30184581e-03  6.26705275e-03  4.61148577e-03  2.55122511e-03
#   3.39912083e-04 -1.76894788e-03 -3.55677800e-03 -4.86643680e-03]
# 10000
# [0.00989923 0.00921029 0.0100582  0.01818642 0.03588106 0.05778379
#  0.07280321 0.07158653 0.05459118 0.03473209 0.03179056 0.06119191
#  0.12376756 0.20299836 0.27198197 0.30662982 0.29791415 0.2565204
#  0.20754944 0.17831728 0.18572644 0.22942491 0.2935201  0.35513733
#  0.3950334  0.4051538  0.39020308 0.36351487 0.34003808 0.33002479
#  0.33598592 0.3535023  0.3746558  0.39199037 0.40120816 0.40184428
#  0.39626917 0.38798729 0.3801659  0.37485541 0.37284861 0.37387447
#  0.37687947 0.38034308 0.38268323 0.38274283 0.38019852 0.37566834
#  0.37041015 0.3657366  0.36245376 0.36061882 0.35970922 0.35904198
#  0.35815314 0.35692032 0.35541788 0.35367855 0.35157264 0.34889787
#  0.34559912 0.34193695 0.33845878 0.33576269 0.33418245 0.33357593
#  0.33334323 0.33267653 0.33092552 0.32790632 0.32400871 0.32004708
#  0.31691287 0.31517601 0.31481224 0.31518599 0.31530967 0.31427301
#  0.31165069 0.30769804 0.30323976 0.29930139 0.2966565  0.29550171
#  0.29540635 0.29554834 0.29511148 0.29364916 0.29124555 0.28841144
#  0.28578182 0.28377504 0.28238509 0.28120865 0.27968968 0.27745455
#  0.27456095 0.27152148 0.269072   0.26778766]
# [0.00099495 0.0009597  0.00100291 0.00134857 0.00189423 0.00240383
#  0.00269821 0.00267557 0.00233648 0.00186365 0.00178299 0.0024737
#  0.00351806 0.00450553 0.00521519 0.00553742 0.00545815 0.00506478
#  0.00455576 0.00422276 0.0043096  0.00478983 0.00541775 0.00595934
#  0.00628517 0.00636517 0.00624662 0.00602922 0.00583128 0.00574478
#  0.00579643 0.00594561 0.00612091 0.00626091 0.0063341  0.00633912
#  0.00629499 0.00622886 0.00616576 0.00612254 0.00610613 0.00611453
#  0.00613905 0.0061672  0.00618614 0.00618662 0.00616602 0.00612918
#  0.00608613 0.00604762 0.00602041 0.00600515 0.00599758 0.00599201
#  0.00598459 0.00597428 0.00596169 0.00594709 0.00592936 0.00590676
#  0.00587877 0.00584754 0.00581772 0.0057945  0.00578085 0.0057756
#  0.00577359 0.00576781 0.00575261 0.00572631 0.00569218 0.00565727
#  0.0056295  0.00561405 0.00561081 0.00561414 0.00561524 0.00560601
#  0.00558257 0.00554705 0.00550672 0.00547084 0.00544662 0.00543601
#  0.00543513 0.00543644 0.00543242 0.00541894 0.00539672 0.0053704
#  0.00534586 0.00532705 0.00531399 0.00530291 0.00528857 0.0052674
#  0.00523986 0.00521077 0.00518722 0.00517482]

# %% [markdown]
# ### Part B
#
# Plot the epistemic uncertainty about the mean position at $t=5$s as a function of the number of samples.
#
# **Solution**:

# %%
# Extract the samples of the final position
sampled_last_position = samples[:, -1, 0]
# Just the numbers from 1 to 100 inclusive
ns = np.arange(1, samples.shape[0] + 1)
# Estimate the running mean positions from samples
mean_positions = np.cumsum(sampled_last_position) / ns
# Estimate the running variance (needed by the CLM)
mean_positions_squared = np.cumsum(sampled_last_position ** 2) / ns
var_positions = mean_positions_squared - mean_positions ** 2
# Apply now the CLM theorem to find the standard deviation corresponding
# to epistemic uncertainty
clm_variance = var_positions / ns
clm_std = np.sqrt(clm_variance)
# Lower bound for mean positions
mean_positions_lower = mean_positions - 1.96 * clm_std
# Upper bound for mean positions
mean_positions_upper = mean_positions + 1.96 * clm_std
# Plot everything
fig, ax = plt.subplots()
ax.plot(ns, mean_positions, label='MC estimate of mean of position')
ax.fill_between(ns, mean_positions_lower, mean_positions_upper,
                color='blue', alpha=0.25, label='Epistemic uncertainty about mean of position')
ax.set_xlabel('Number of samples')
ax.set_ylabel('Mean of position at final step')
plt.legend(loc='best');

# %% [markdown]
# ### Part C
# Repeat part A and B for the squared response.
# That is, do exactly the same thing as above, but consider $y^2(t)$ and $\dot{y}^2(t)$ instead of $y(t)$ and $\dot{y}(t)$.
# How many samples do you need to estimate the mean squared response at $t=5$s with negligible epistemic uncertainty?
#
# **Solution**:

# %%
# Note that I just copy-pasted the code from above and made some modifications
# Then I went't to the very first cell

# Prediction for positions
mean_position2 = np.mean(sampled_positions ** 2, axis=0)
# We are going to apply the CLM to get the 95% epistemic uncertainty
# We need an estimate of the variance at each timestep
var_position2 = np.var(sampled_positions ** 2, axis=0)
# Now get the CLM variance (which is this variance divided by the number of samples)
clm_var_position2 = var_position2 / samples.shape[0]
# and the standard devivation used in CLM
clm_std_position2 = np.sqrt(clm_var_position2)
# Lower bound to position
mean_position2_lower = mean_position2 - 1.96 * clm_std_position2
# Upper bound to position
mean_position2_upper = mean_position2 + 1.96 * clm_std_position2

# Plot it
fig, ax = plt.subplots()
ax.plot(solver.t, mean_position2, label='Mean position squared')
ax.fill_between(solver.t, mean_position2_lower, mean_position2_upper,
                label='95% credible interval', color='blue', alpha=0.25)
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$y^2(t)$')
plt.legend(loc='best');

# Prediction for velocities
mean_velocity2 = np.mean(sampled_velocities ** 2, axis=0)
# We are going to apply the CLM to get the 95% epistemic uncertainty
# We need an estimate of the variance at each timestep
var_velocity2 = np.var(sampled_velocities ** 2, axis=0)
# Now get the CLM variance (which is this variance divided by the number of samples)
clm_var_velocity2 = var_velocity2 / samples.shape[0]
# and the standard devivation used in CLM
clm_std_velocity2 = np.sqrt(clm_var_velocity2)
# Lower bound to position
mean_velocity2_lower = mean_velocity2 - 1.96 * clm_std_velocity2
# Upper bound to position
mean_velocity2_upper = mean_velocity2 + 1.96 * clm_std_velocity2

# Plot it
fig, ax = plt.subplots()
ax.plot(solver.t, mean_velocity2, 'r', label='Mean velocity')
ax.fill_between(solver.t, mean_velocity2_lower, mean_velocity2_upper,
                label='95% credible interval', color='red', alpha=0.25)
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$\dot{y}(t)$ (Velocity)')
plt.legend(loc='best');

# Estimate the running mean positions from samples
mean_positions2 = np.cumsum(sampled_last_position ** 2) / ns
# Estimate the running variance (needed by the CLM)
mean_posisions2_squared = np.cumsum(sampled_last_position ** 4) / ns
var_positions2 = mean_posisions2_squared - mean_positions2 ** 2
# Apply now the CLM theorem to find the standard deviation corresponding
# to epistemic uncertainty
clm_variance2 = var_positions2 / ns
clm_std2 = np.sqrt(clm_variance2)
# Lower bound for mean positions
mean_positions2_lower = mean_positions2 - 1.96 * clm_std2
# Upper bound for mean positions
mean_positions2_upper = mean_positions2 + 1.96 * clm_std2
# Plot everything
fig, ax = plt.subplots()
ax.plot(ns, mean_positions, label='MC estimate of mean of position squared')
ax.fill_between(ns, mean_positions_lower, mean_positions_upper,
                color='blue', alpha=0.25, label='Epistemic uncertainty about mean of position squared')
ax.set_xlabel('Number of samples')
ax.set_ylabel('Mean of position squared at final step')
plt.legend(loc='best');

# %% [markdown]
# ### Part D
#
# Now that you know how many samples you need to estimate the mean of the response and the square response, use the formula:
# $$
# \mathbb{V}[y(t)] = \mathbb{E}[y^2(t)] - \left(\mathbb{E}[y(t)]\right)^2,
# $$
# and similarly for $\dot{y}(t)$, to estimate the variance of the position and the velocity with negligible epistemic uncertainty.
# Plot both quantities as a function of time.
#
# **Solution**:

# %%
var_position = mean_position2 - mean_position ** 2
var_velocity = mean_velocity2 - mean_velocity ** 2

fig, ax = plt.subplots()
ax.plot(solver.t, var_position, 'b')
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$\mathbb{V}[y(t)]$')

fig, ax = plt.subplots()
ax.plot(solver.t, var_velocity, 'r')
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$\mathbb{V}[\dot{y}(t)]$');

# %% [markdown]
# ### Part E
#
# Put together the estimated mean and variance to plot a 95\% predictive interval for the position and the velocity as functions of time.
#
# **Solution**:

# %%
std_position = np.sqrt(var_position)
positions_lower = mean_position - 1.96 * std_position
positions_upper = mean_position + 1.96 * std_position
fig, ax = plt.subplots()
ax.plot(solver.t, mean_position, 'b', label='Mean $y(t)$')
ax.fill_between(solver.t, positions_lower, positions_upper, color='b', alpha=0.25,
                label='95% predictive interval')
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$y(t)$')
plt.legend(loc='best')

std_velocity = np.sqrt(var_velocity)
velocity_lower = mean_velocity - 1.96 * std_velocity
velocity_upper = mean_velocity + 1.96 * std_velocity
fig, ax = plt.subplots()
ax.plot(solver.t, mean_velocity, 'b', label='Mean $\dot{y}(t)$')
ax.fill_between(solver.t, velocity_lower, velocity_upper, color='b', alpha=0.25,
                label='95% predictive interval')
ax.set_xlabel('$t$ (Time)')
ax.set_ylabel('$y(t)$');

# %% [markdown]
# -End-
